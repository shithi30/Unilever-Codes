# %%
## ref
# - C:\Users\Shithi.Maitra\Unilever Codes\Scraping Scripts\Packshots Daraz
# - C:\Users\Shithi.Maitra\Unilever Codes\Scraping Scripts\Packshots Daraz Grammage

# import
from selenium import webdriver
from bs4 import BeautifulSoup
from random import shuffle
import time
import requests
import warnings
from pathlib import Path
from os.path import basename
from PIL import Image
import numpy as np
import zipfile
import win32com.client

# preferences

start_time = time.time()
warnings.filterwarnings("ignore")
print("Packshots with no grammage info are displayed.")

options = webdriver.ChromeOptions()
options.add_argument("ignore-certificate-errors")

# open window
driver = webdriver.Chrome(options = options)
driver.maximize_window()

# folder(s)

folder = "Packshots Daraz"
filenames = []
output_dir = Path.cwd() / folder
output_dir.mkdir(parents=True, exist_ok=True)
folder_zip = zipfile.ZipFile(folder + ".zip", 'w')

folder_gm = "Packshots Daraz Grammage"
filenames_gm = []
output_dir_gm = Path.cwd() / folder_gm
output_dir_gm.mkdir(parents=True, exist_ok=True)
folder_gm_zip = zipfile.ZipFile(folder_gm + ".zip", 'w')

# sources
filenames_src = []
filenames_gm_src = []

# link
pg = 0
while(1): 
    pg = pg + 1
    link = "https://www.daraz.com.bd/unilever-bangladesh/?from=wangpu&lang=en&langFlag=en&page=" + str(pg) + "&pageTypeId=2&q=All-Products"
    driver.get(link)

    # scroll smooth
    y = 500
    for timer in range(0, 10):
        time.sleep(1)
        driver.execute_script("window.scrollTo(0, " + str(y) + ")")
        y = y + 500

    # soup
    soup_init = BeautifulSoup(driver.page_source, "html.parser")
    soup = soup_init.find_all("a", attrs={"id": "id-a-link"})
    shuffle(soup)

    # scrape
    img_count = len(soup)
    if img_count == 0: break 
    print("\nFetching packshots from page: " + str(pg))
    for i in range(0, img_count):

        # SKU
        try: val = soup[i].find("div", attrs={"id": "id-title"}).get_text()
        except: val = ""
        sku = "" + val
    
        # packshot
        img_link = soup[i].find("img", attrs={"id": "id-img"})["src"]    
        img_data = Image.open(requests.get(img_link, stream=True, verify=False).raw).resize((600, 600)).convert("RGB")
        filenames_src.append(img_link)

        # save
        filename = sku.replace(' ', "") + ".jpg"
        filenames.append(filename)
        filepath = str(output_dir) + "\\" + filename
        img_data.save(filepath, "JPEG")
        folder_zip.write(filepath, basename(filepath))
        
        # grammage
        gm = 1
        for x in range(590, 595):
            for y in range(450, 455):
                if img_data.getpixel((x, y)) == (255, 255, 255): 
                    gm = 0
        pix = img_data.getpixel((595, 595))
        if gm == 0 and np.argmax(list(pix)) != 1 and pix != (255, 255, 255): gm = 1
                
        # save, report
        if (gm == 0): 
            filenames_gm_src.append(img_link)
            filenames_gm.append(filename)
            img_data.save(str(output_dir_gm) + "\\" + filename, "JPEG")
            folder_gm_zip.write(filepath, basename(filepath))
            display(img_data.resize(tuple(int(s*0.30) for s in img_data.size)))
        print(str(i+1) + ". " + filename)

# close window
driver.close()
        
# zip
folder_zip.close()
folder_gm_zip.close()

# seperate
filenames_src = [f for f in filenames_src if f not in filenames_gm_src]
# Out:
# Packshots with no grammage info are displayed.
#
# Fetching packshots from page: 1
# 1. BoostChocolateJar400g(PowderDrink).jpg
# 2. VimDishwashingBar300g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 3. DoveShampooIntenseRepair170ml.jpg
# 4. RinLiquidDetergent800ml.jpg
# 5. DomexToiletCleaningLiquidOceanFresh750mlx2.jpg
# 6. Pond'sFaceCleanserScrubPureBrightMineralClaywithCharcoal90g.jpg
# 7. CloseupToothpasteMentholFresh150g+freeMug.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 8. ClearShampooMenCoolSportMentholAntiDandruff315ml.jpg
# 9. SunsilkShampooHijabRefresh330ml(15%Extra).jpg
# 10. BuyVimLiquidDishwash1Ltrgetscrubberfree.jpg
# 11. ClearMenShampooCoolSportMentholAntiDandruff450ml.jpg
# 12. RinLiquidDetergent400ml.jpg
# 13. PondsMenFacewashAcneSolution100gx2.jpg
# 14. PepsodentKidsToothpasteSweetStrawberry45g.jpg
# 15. SurfExcelMaticLiquidDetergentTopLoad1L.jpg
# 16. JuniorHorlicksHealthandNutritionDrinkStage2(5+Years)Jar500g(PowderDrink).jpg
# 17. ComfortFabricConditionerSenseofPleasurewithJasmineFresh2L(UI).jpg
# 18. Pond'sMenFacewashAcneSolutionFacialFoam100g.jpg
# 19. Glow&LovelyAdvancedMultivitaminCream47g.jpg
# 20. Pond'sFacialFoamBrightBeautyMineralClaywithVitaminB3+90g.jpg
# 21. LifebuoyHandwash(Soap)LemonFreshBottle1L.jpg
# 22. ClearMenShampooCoolSportMentholAntiDandruff80ml.jpg
# 23. SunsilkShampooVolume195ml.jpg
# 24. ClearShampooAntiHairfallAntiDandruff330ml.jpg
# 25. StandardHorlicksHealthandNutritionDrinkJar250g.jpg
# 26. SunsilkShampooHairFallSolution330ml(15%Extra).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 27. ClearMenCoolingItchControlAnti-DandruffShampoo315ml(UnileverOriginal).jpg
# 28. Glow&LovelyFaceCreamAdvancedMultivitamin100g.jpg
# 29. ClinicPlusShampooStrongandLong340ml.jpg
# 30. DomexToiletCleaningLiquidLimeFresh750mlx2.jpg
# 31. Pond'sFaceWashOilControl100g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 32. ClearMenAnti-HairFallAnti-DandruffShampoo300ml(Imported).jpg
# 33. Pond'sFaceWashPureWhite50g.jpg
# 34. Pond'sFaceWashPureDetox100g.jpg
# 35. Pond’sSuperLightGelMoisturiser98g.jpg
# 36. MaltovaHealthandNutritionDrinkBIB400g.jpg
# 37. VIMDishwashingLiquid1lt.jpg
# 38. TresemmeConditionerKeratinSmooth190ml.jpg
# 39. Pond'sMenFacewashLightningOilClearIcyScrub100g.jpg
# 40. StandardHorlicksHealthandNutritionDrinkJar1kg.jpg
#
# Fetching packshots from page: 2
# 1. SurfExcelMaticLiquidDetergentTopLoad1L.jpg
# 2. ClinicPlusShampooStrongandLong340ml.jpg
# 3. ClearShampooAntiHairfallAntiDandruff330ml.jpg
# 4. ComfortFabricConditionerSenseofPleasurewithJasmineFresh2L(UI).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 5. DoveShampooIntenseRepair170ml.jpg
# 6. MaltovaHealthandNutritionDrinkBIB400g.jpg
# 7. ClearMenShampooCoolSportMentholAntiDandruff80ml.jpg
# 8. Pond'sMenFacewashLightningOilClearIcyScrub100g.jpg
# 9. Pond'sFaceWashOilControl100g.jpg
# 10. VIMDishwashingLiquid1lt.jpg
# 11. PondsMenFacewashAcneSolution100gx2.jpg
# 12. SunsilkShampooVolume195ml.jpg
# 13. PepsodentKidsToothpasteSweetStrawberry45g.jpg
# 14. VimDishwashingBar300g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 15. ClearShampooMenCoolSportMentholAntiDandruff315ml.jpg
# 16. Pond’sSuperLightGelMoisturiser98g.jpg
# 17. ClearMenShampooCoolSportMentholAntiDandruff450ml.jpg
# 18. SunsilkShampooHijabRefresh330ml(15%Extra).jpg
# 19. DomexToiletCleaningLiquidLimeFresh750mlx2.jpg
# 20. Pond'sFaceCleanserScrubPureBrightMineralClaywithCharcoal90g.jpg
# 21. TresemmeConditionerKeratinSmooth190ml.jpg
# 22. DomexToiletCleaningLiquidOceanFresh750mlx2.jpg
# 23. Pond'sFaceWashPureDetox100g.jpg
# 24. StandardHorlicksHealthandNutritionDrinkJar1kg.jpg
# 25. SunsilkShampooHairFallSolution330ml(15%Extra).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 26. ClearMenCoolingItchControlAnti-DandruffShampoo315ml(UnileverOriginal).jpg
# 27. Glow&LovelyAdvancedMultivitaminCream47g.jpg
# 28. RinLiquidDetergent400ml.jpg
# 29. StandardHorlicksHealthandNutritionDrinkJar250g.jpg
# 30. CloseupToothpasteMentholFresh150g+freeMug.jpg
# 31. BoostChocolateJar400g(PowderDrink).jpg
# 32. RinLiquidDetergent800ml.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 33. ClearMenAnti-HairFallAnti-DandruffShampoo300ml(Imported).jpg
# 34. Pond'sFacialFoamBrightBeautyMineralClaywithVitaminB3+90g.jpg
# 35. LifebuoyHandwash(Soap)LemonFreshBottle1L.jpg
# 36. Pond'sMenFacewashAcneSolutionFacialFoam100g.jpg
# 37. BuyVimLiquidDishwash1Ltrgetscrubberfree.jpg
# 38. JuniorHorlicksHealthandNutritionDrinkStage2(5+Years)Jar500g(PowderDrink).jpg
# 39. Pond'sFaceWashPureWhite50g.jpg
# 40. Glow&LovelyFaceCreamAdvancedMultivitamin100g.jpg
#
# Fetching packshots from page: 3
# 1. DoveShampooHijabNatural330ml.jpg
# 2. VaselineLotionHealthyBright200ml.jpg
# 3. PepsodentToothpasteSensitiveExpertProfessional140g.jpg
# 4. Pond'sFaceWashPureDetox50g.jpg
# 5. Pond'sVanishingCream50g.jpg
# 6. DomexToiletCleaningLiquidOceanFresh500ml(Bundleof2).jpg
# 7. TresemmeShampooBotaniqueNourishandReplenish580ml.jpg
# 8. VimLiquidDishwash250ml.jpg
# 9. DoveBeautyBarSoapWhite135g(MadeinGermany).jpg
# 10. SunsilkShampooFreshness195ml.jpg
# 11. HorlicksLiteHealthandNutritionDrinkJar400g(PowderDrink).jpg
# 12. JuniorHorlicksHealthandNutritionDrinkStage2(5+Years)Jar500g(PowderDrink).jpg
# 13. Mother'sPLUSHorlicksHealthandNutritionDrinkBIB350g.jpg
# 14. LuxBodyWashFrenchRose&Almond245ml.jpg
# 15. BuyDomexToiletCleaningLiquidOceanFresh500mlGetMugFree.jpg
# 16. LifebuoyHandwash(Soap)TotalBottle1L.jpg
# 17. Glow&LovelyInstaglowFacewashwithMultivitamins100g.jpg
# 18. Pond'sFacialScrubNourishing100g.jpg
# 19. ClearMenShampooCoolSportMentholAntiDandruff170ml.jpg
# 20. KnorrSoupHotandSourChicken31g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 21. ClearMenCoolSportMentholAnti-DandruffShampoo310ml(UnileverOriginal).jpg
# 22. PondsDayCreamWhiteBeauty50g.jpg
# 23. DoveBeautyBarSoapPamperingSheaButter90g.jpg
# 24. StandardHorlicksHealthandNutritionDrinkSuperValuePack400g.jpg
# 25. Glow&LovelyFaceCreamAyurvedicCare25g.jpg
# 26. ClearShampooCompleteActiveCareAntiDandruff330ml.jpg
# 27. SurfExcelMaticLiquidDetergentTopLoad500ml.jpg
# 28. PondsBrightBeautyCreamSerum35g.jpg
# 29. TresemmeShampooKeratinSmooth340ml.jpg
# 30. VimLiquidDishwash500mlFreeVim75mlPouch.jpg
# 31. DoveBeautyBarSoapWhite60g.jpg
# 32. Pond'sFaceWashDaily50g.jpg
# 33. PepsodentToothpasteSensitiveExpertGumCare140g.jpg
# 34. Pond'sDailyFaceWash100g.jpg
# 35. Pond'sMenFacewashLightningOilClearIcyScrub50g.jpg
# 36. LifebuoyHandwash(Soap)LemonFreshRefill170ml.jpg
# 37. VaselineLotionDeepRestore300ml.jpg
# 38. PondsBrightBeautyCreamSerum35g.jpg
# 39. KnorrThaiSoup28g(Bundleof5).jpg
# 40. Pond'sFaceWashBrightBeauty100g.jpg
#
# Fetching packshots from page: 4
# 1. LifebuoySkinCleansingSoapBarLemonFresh100g.jpg
# 2. Glow&LovelyFaceCreamAyurvedicCare50g.jpg
# 3. LifebuoySkinCleansingSoapBarTotal100g(Bundleof4).jpg
# 4. DomexToiletCleaningLiquidLimeFresh500mlGetaDustpanFree(Bundleof2).jpg
# 5. Glow&HandsomeFaceCreamRapidActionInstantBrightness50g.jpg
# 6. GlowandLovelyCreamAyurvedicCare50g.jpg
# 7. LifebuoyHandwash(Soap)CarePump200ml.jpg
# 8. HorlicksChocolateFlavourJar500g(PowderDrink).jpg
# 9. LifebuoyHandwash(Soap)CareRefill170ml.jpg
# 10. DoveBeautyBarSoapWhite90g(Bundleof3).jpg
# 11. SunsilkShampooVolume375ml.jpg
# 12. Pond'sDayCreamBrightBeauty23g.jpg
# 13. KnorrHot&SourSoup31g(Bundleof4).jpg
# 14. DomexToiletCleaningLiquidOceanFresh750mlGetaBasinBrushFree.jpg
# 15. DoveBodyLotionNourishingRadiance250ml.jpg
# 16. DomexToiletCleaningLiquidLimeFresh750ml(FreeGift).jpg
# 17. JuniorHorlicksHealthandNutritionDrinkStage1(2-5Years)Jar500g(PowderDrink).jpg
# 18. DoveShampooHairfallRescue650ml.jpg
# 19. StandardHorlicksHealthandNutritionDrinkJar1kg.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 20. ClearShampooCompleteActiveCareAntiDandruff170ml.jpg
# 21. SunsilkShampooPerfectStraight330ml(15%Extra).jpg
# 22. KnorrSoupChickenCorn24g.jpg
# 23. BuyDomexToiletCleaningLiquidLimeFresh500mlGetMugFree.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 24. SunsilkShampooLusciouslyThick&Long340ml.jpg
# 25. PepsodentToothpasteGermi-Check90g.jpg
# 26. StandardHorlicksHealthandNutritionDrinkJar1kg.jpg
# 27. LifebuoySkinCleansingSoapBarCare100g(ComboPack).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 28. ClearMenDeepCleanseAnti-DandruffShampoo320ml(UnileverOriginal).jpg
# 29. DoveShampooIntenseRepair650ml.jpg
# 30. ClearMenShampooCoolSportMentholAntiDandruff80ml.jpg
# 31. HorlicksHealthandNutritionDrinkJar500g.jpg
# 32. SunsilkShampooStunningBlackShine-450ml.jpg
# 33. LifebuoyHandwash(Soap)CareRefill170ml(bundleof3).jpg
# 34. LuxSoapBarVelvetGlow150g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 35. Glow&LovelyInstaglowFacewashwithMultivitamins50g.jpg
# 36. SunsilkShampooHairFallSolution340ml.jpg
# 37. LifebuoyHandwash(Soap)TotalRefill170ml.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 38. SunsilkHealther&LongShampoo280ml(UnileverOriginal).jpg
# 39. TresemmeShampooHairFallDefense580ml.jpg
# 40. DoveBeautyBarSoapGentleExfoliating135g.jpg
#
# Fetching packshots from page: 5
# 1. Women'sPLUSHorlicksHealthandNutritionDrinkJar400g.jpg
# 2. PepsodentToothpasteGermi-Check42g.jpg
# 3. SunsilkShampooVolume375ml.jpg
# 4. ClearShampooCompleteActiveCare80ml.jpg
# 5. LifebuoySkinCleansingSoapBarLemonFresh100g.jpg
# 6. SunsilkShampooStunningBlackShine450ml.jpg
# 7. LifebuoySkinCleansingSoapBarTotal150g.jpg
# 8. LifebuoyHandwash(Soap)LemonFreshRefill170ml.jpg
# 9. DoveShampooHairfallRescue170ml.jpg
# 10. LifebuoySkinCleansingSoapBarTotal100g(ComboPack).jpg
# 11. LifebuoyCoolSoapBar100gx2(combo).jpg
# 12. VimLiquidDishwash1L.jpg
# 13. LuxSoapBarVelvetGlow100g(ComboPack).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 14. DoveConditionerHairfallRescue170ml.jpg
# 15. PepsodentToothpasteGermi-Check140g.jpg
# 16. DoveIntenseRepairShampoo650ml.jpg
# 17. Pond'sMenFacewashAcneSolutionFacialFoam50g.jpg
# 18. LifebuoySkinCleansingSoapBarCare100g(25gExtra).jpg
# 19. KnorrSoupHotandSourChicken31g.jpg
# 20. VaselineLotionDeepRestore200ml.jpg
# 21. VaselineLotionHealthyBright300ml.jpg
# 22. LuxSoapBarSoftGlow150g.jpg
# 23. Glow&LovelyCreamWinter25g.jpg
# 24. KnorrChickenCornSoup24g(Bundleof5).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 25. DoveBeautyBarSoapPink135g.jpg
# 26. VimLiquidDishwash500ml.jpg
# 27. DoveShampooHairfallRescue330ml+CP.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 28. DoveIntenseRepairConditioner660ml(UnileverOriginal).jpg
# 29. TresemmeShampooColorRevitalise828ml(UI).jpg
# 30. Pond'sFaceWashPureDetox100g(PuffFree).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 31. ClearMenCoolingItchControlAnti-DandruffShampoo650ml(UnileverOriginal).jpg
# 32. LifebuoySkinCleansingSoapBarLemonFresh150g(Bundleof3).jpg
# 33. ClearMenShampooCoolSportMentholAntiDandruff330ml.jpg
# 34. Glow&LovelyFaceCreamAdvancedMultivitamin23g.jpg
# 35. SunsilkShampooStunningBlackShine340ml.jpg
# 36. LifebuoySkinCleansingSoapBarCare150g.jpg
# 37. DomexToiletCleaningLiquidLimeFresh500mlDustpanFree.jpg
# 38. DoveShampooHealthyGrow330ml(15%Extra).jpg
# 39. PepsodentToothpasteGermi-Check190gm.jpg
# 40. LifebuoyHandwash(Soap)LemonFreshPump200ml.jpg
#
# Fetching packshots from page: 6
# <PIL.Image.Image image mode=RGB size=180x180>
# 1. DoveStraight&SilkyShampoo330ml(UnileverOriginal).jpg
# 2. DoveShampooNourishingOilCare330ml(15%Extra).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 3. ClearCompleteSoftCareAnti-DandruffShampoo300ml(UnileverOriginal).jpg
# 4. Pond'sFaceWashOilControl50g.jpg
# 5. SurfExcelSyntheticLaundryDetergentPowder1kg.jpg
# 6. VimLiquidDishwash250ml(Bundleof2).jpg
# 7. Pond'sFaceWashBrightBeauty20g.jpg
# 8. LifebuoyHandwash(Soap)TotalRefill170ml(Bundleof3).jpg
# 9. SunsilkShampooPerfectStraight380ml.jpg
# 10. Glow&HandsomeFaceCreamRapidActionInstantBrightness25g.jpg
# 11. Glow&LovelyFacewashInstaglowwithMultivitamins50g.jpg
# 12. WheelWashing(Detergent)Powder2in1Clean&Fresh2Kg.jpg
# 13. KnorrSoupThai28g.jpg
# 14. SunsilkShampooLusciouslyThick&Long450ml.jpg
# 15. LifebuoySkinCleansingSoapBarCoolFresh100g(Bundleof4).jpg
# 16. SurfExcelSyntheticLaundryDetergentPowder1kg.jpg
# 17. LifebuoySkinCleansingSoapBarTotal100g.jpg
# 18. SunsilkShampooLusciouslyThick&Long340ml.jpg
# 19. VimDishwashPowder500g.jpg
# 20. DomexToiletCleaningLiquidLimeFresh500mlGetaDustpanFree.jpg
# 21. Glow&LovelyFaceCream(BB)BlemishBalm40g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 22. TresemmeShampooKeratinSmooth700ml(UI).jpg
# 23. PepsodentToothpasteSensitiveExpertProfessional40g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 24. SunsilkBlackShineShampoo300ml(UnileverOriginal).jpg
# 25. DoveBeautyBarSoapPink100g(Bundleof3).jpg
# 26. SunsilkShampooLusciouslyThick&Long650ml.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 27. SunsilkHealther&LongShampoo560ml(UnileverOriginal).jpg
# 28. GlucoMaxD75g(PowderDrink)(Comboof12packs).jpg
# 29. SunsilkShampooStunningBlackShine330ml(15%Extra).jpg
# 30. LifebuoyHandwash(Soap)LemonFreshRefill170ml(Bundleof3).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 31. SunsilkPerfectStraightShampoo560ml(UnileverOriginal).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 32. LifebuoySkinCleansingSoapBarLemonFresh150g.jpg
# 33. VaselineLotionDeepRestore100ml.jpg
# 34. DoveShampooIntenseRepair170ml.jpg
# 35. LifebuoySoapBarCare150g.jpg
# 36. GlucoMaxD200gBIB(PowderDrink).jpg
# 37. VimDishwashingLiquid1ltx2.jpg
# 38. LuxSoapBarSoftGlow100g(ComboPack).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 39. DomexToiletCleaningLiquidOceanFresh750ml.jpg
# 40. Glow&HandsomeFacewashRapidActionInstantBrightness50g.jpg
#
# Fetching packshots from page: 7
# 1. LifebuoySkinCleansingSoapBarTotal150g(Bundleof3).jpg
# 2. DoveShampooOxygenMoisture330ml.jpg
# 3. VaselineLotionHealthyBright400ml.jpg
# 4. LuxSoapBarSoftGlow35g.jpg
# 5. LuxSoapBarVelvetGlow100g(Bundleof3).jpg
# 6. RinAdvancedDetergentPowder500g.jpg
# 7. LuxSoapBarVelvetGlow75g.jpg
# 8. VaselinePetroleumJelly50ml.jpg
# 9. Pond'sBodyLotionMoisturising200ml.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 10. DoveBeautyBarSoapPamperingSheaButter135g.jpg
# 11. LifebuoySkinCleansingSoapBarTotal125g.jpg
# 12. LifebuoySkinCleansingSoapBarCoolFresh100g.jpg
# 13. StandardHorlicksHealthandNutritionDrinkJar500g.jpg
# 14. Glow&LovelyFacewashInstaglowwithMultivitamins100g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 15. DoveStraight&SilkyConditioner660ml(UnileverOriginal).jpg
# 16. LuxSoapBarSoftGlow75g.jpg
# 17. Glow&LovelySkinCreamMultivitamin23gm.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 18. PepsodentToothpowder95gm.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 19. GlucomaxD400GBib.jpg
# 20. DoveBeautyBarSoapWhite90g(UI).jpg
# 21. Glow&LovelyCreamWinter50g(AloeFreshPetroleumJelly9mlFree).jpg
# 22. DoveBeautyBarSoapWhite135g(Bundleof2).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 23. ClearExtraStrengthAnti-DandruffShampoo300ml(UnileverOriginal).jpg
# 24. LifebuoySkinCleansingSoapBarCare100g(Bundleof4).jpg
# 25. RinAdvancedSyntheticLaundryDetergentPowder1kg.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 26. SunsilkHairCareSmooth&ManageableShampoo300ml(UnileverOriginal).jpg
# 27. DoveShampooIntenseRepair330ml.jpg
# 28. LifebuoySkinCleansingSoapBarLemonFresh100g(ComboPack).jpg
# 29. KnorrKrispyFriedChickenMix75g.jpg
# 30. ClearMenCoolingItchControlAnti-DandruffShampoo315ml(UnileverOriginal).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 31. DoveBeautyBarSoapWhite90g.jpg
# 32. DoveShampooNourishingOilCare170ml.jpg
# 33. DoveIntenseRepairShampoo6ml(Buy11Get1Free).jpg
# 34. VaselineLotionDeepRestore400ml.jpg
# 35. SurfExcelSyntheticLaundryDetergentPowder1kg(18.TKOFF).jpg
# 36. SunsilkShampooStunningBlackShine80ml.jpg
# 37. DoveShampooHairfallRescue450ml.jpg
# 38. Glow&LovelyFaceCream(BB)BlemishBalm18g.jpg
# 39. TresemmeShampooColorRevitalise580ml.jpg
# 40. DoveShampooHairfallRescue330ml.jpg
#
# Fetching packshots from page: 8
# 1. SunsilkShampooStunningBlackShine380ml.jpg
# 2. LifebuoySkinCleansingSoapBarLemonFresh100g(Bundleof4).jpg
# 3. WheelWashingPowder2in1Clean&Fresh500g.jpg
# 4. DoveBeautyBarSoapPink135g(Bundleof2).jpg
# 5. SurfExcelSyntheticLaundryDetergentPowder500g.jpg
# 6. DoveHairfallShampoo6ml(Buy11Get1Free).jpg
# 7. KnorrSoupThai28g.jpg
# 8. KnorrSoupThai28g.jpg
# 9. Pond'sBrightBeautyFacewash50g.jpg
# 10. DoveShampooIntenseRepair450ml.jpg
# 11. LifebuoySkinCleansingSoapBarLemonFresh100g.jpg
# 12. SunsilkShampooFreshness375mlCP.jpg
# 13. DomexToiletCleaningLiquidLimeFresh750ml(FreeGift).jpg
# 14. LifebuoyHandwash(Soap)CareRefill170ml.jpg
# 15. DoveBeautyBarSoapPink90g.jpg
# 16. WheelWashing(Detergent)Powder2in1Clean&Fresh1Kg.jpg
# 17. LuxSoapBarSoftGlow100g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 18. Glow&LovelyskincreamMultivitamin47gm.jpg
# 19. SurfExcelSyntheticLaundryDetergentPowder200g.jpg
# 20. KnorrSoupHotandSourChicken31g.jpg
# 21. Glow&LovelyFaceCreamAdvancedMultivitamin80g.jpg
# 22. DoveBeautyBarSoapPink100g.jpg
# 23. LifebuoySoapBarCare125g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 24. DoveHairfallRescueShampoo410ml(UnileverOriginal).jpg
# 25. Lifebuoyhealthsoaptotal125gm.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 26. DoveStraight&SilkyShampoo680ml(UnileverOriginal).jpg
# 27. LifebuoySoapBarTotal150g.jpg
# 28. PondsBodyLotionMoisturising100ml.jpg
# 29. Pond'sFaceWashBrightBeauty50g.jpg
# 30. WheelWashingLaundryBar125g.jpg
# 31. RinAdvancedSyntheticLaundryDetergentPowder2kg.jpg
# 32. LifebuoyHandwash(Soap)TotalRefill170ml(ComboPack).jpg
# 33. TresemmeShampooAntiBreakage828ml(UI).jpg
# 34. LifebuoyHandwash(Soap)Total5L.jpg
# 35. DoveShampooIntenseRepair80ml.jpg
# 36. SunsilkShampooPerfectStraight340ml.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 37. LifebuoyHandwash(Soap)CareRefill170ml(ComboPack).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 38. DoveIntenseRepairShampoo330ml(UnileverOriginal).jpg
# 39. LuxSoapBarVelvetGlow75g.jpg
# 40. CloseupToothpasteMentholFresh100g.jpg
#
# Fetching packshots from page: 9
# 1. SunsilkShampooStunningBlackShine170ml(15%Extra).jpg
# 2. PepsodentToothpasteSensitiveExpertFresh140gx2.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 3. WheelWashingLaundryBar125g.jpg
# 4. DomexToiletCleaningLiquidOceanFresh750mlGetaBasinBrushFree(Bundleof2).jpg
# 5. VimDishwashingBar125g.jpg
# 6. VaselineLotionMosquitoDefense100ml.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 7. PondsFlawlessWhiteDeepWhiteningFacialFoam100gm.jpg
# 8. ComfortFabricConditionerTouchofLove2L.jpg
# 9. LuxSoapBarVelvetGlow125g(Bundleof3).jpg
# 10. VaselineLotionHealthyBright100ml.jpg
# 11. Pond'sFaceWashOilControl100g(PuffFree).jpg
# 12. CifStainRemoverCreamLemon500ml.jpg
# 13. CifStainRemoverCreamPink500ml.jpg
# 14. WheelWashing(Detergent)Powder2in1Clean&Fresh500g.jpg
# 15. CIFFLOORCLEANEROCEAN950MLBUY1GET1FREE.jpg
# 16. CifStainRemoverCreamOriginal500ml.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 17. DoveBeautyBarWhite90gX3(Combo).jpg
# 18. Pond'sFaceWashBrightBeauty100g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 19. PepsodentKidsToothpasteAwesomeOrange45g.jpg
# 20. LuxBodyWashBlackOrchidScent&JuniperOil245ml.jpg
# 21. LifebuoyHandwash(Soap)TotalPump200ml.jpg
# 22. Pond'sFaceWashBrightBeauty100g(PuffFree).jpg
# 23. WheelWashing(Detergent)Powder2in1Clean&Fresh200g.jpg
# 24. KnorrSoupChickenCorn24g(Bundleof6).jpg
# 25. PepsodentToothpasteSensitiveExpertProfessional80g.jpg
# 26. Pond'sBrightBeautyCream50g(Imported).jpg
# 27. VimDishwashingBar125g(Buy5Get8tkOff).jpg
# 28. DoveShampooHairfallRescue650ml.jpg
# 29. VaselineLotionDeepRestore300mlwithvaselinePetroleumJellyFree.jpg
# 30. DoveShampooIntenseRepair330ml(15%Extra).jpg
# 31. Pond'sDayCreamBrightBeauty35g.jpg
# 32. Pond'sBodyLotionMoisturising100ml.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 33. ClearMenCoolSportMentholAnti-DandruffShampoo170ml(UnileverOriginal).jpg
# 34. DomexToiletCleaningLiquidLimeFresh750ml(Bundleof2).jpg
# 35. CifFloorCleanerWildOrchid950ml.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 36. PondsFaceWashPureWhite50g.jpg
# 37. VaselineLotionHealthyBright200ml.jpg
# 38. PondsMenFacewashAcneSolution100g.jpg
# 39. CifFloorCleanerOceanBreeze950ml.jpg
# 40. StandardHorlicksHealthandNutritionDrinkBIB500g.jpg
#
# Fetching packshots from page: 10
# <PIL.Image.Image image mode=RGB size=180x180>
# 1. DoveBeautyBarSoapPink135g(UI).jpg
# 2. GlucoMaxD400gBIBContainerFree.jpg
# 3. SunsilkShampooFreshness375ml.jpg
# 4. Pond'sColdCream28g.jpg
# 5. StandardHorlicksHealthandNutritionDrink18gm(Comboof12packs).jpg
# 6. SunsilkConditionerPerfectStraight80ml.jpg
# 7. RinFebricSolutionAdvanced2kg(FREEgift).jpg
# 8. PepsodentToothpasteGermi-Check200g.jpg
# 9. PondsFaceWashWhiteBeauty100g.jpg
# 10. VaselineLotionHealthyBright300ml.jpg
# 11. CIFFLOORCLEANERORCHID950MLBUY1GET1FREE.jpg
# 12. Women'sPLUSHorlicksHealthandNutritionDrinkJar400g.jpg
# 13. VaselineLotionDeepRestore300ml(100mlpetroliumJellyFree).jpg
# 14. TresemmeShampooKeratinSmooth185ml.jpg
# 15. LuxSoapBarSoftGlow100g(Bundleof3).jpg
# 16. PepsodentToothpasteSensitiveExpertFresh140g.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 17. DoveBeautyBarSoapWhite100g.jpg
# 18. DomexToiletCleaningLiquidOceanFresh500mlGetaDustpanFree.jpg
# 19. SunsilkShampooPerfectStraight340mlScrunchFree.jpg
# 20. KnorrSoupChickenCorn24g(Bundleof3).jpg
# 21. PondsMenFacewashLightningOilClear100gx2.jpg
# 22. SunsilkShampooLusciouslyThick&Long330ml(15%Extra).jpg
# 23. DoveBodyLotionNourishingRadiance250ml.jpg
# 24. Glow&HandsomeFacewashRapidActionInstantBrightness100g.jpg
# 25. Pond'sColdCream50g.jpg
# 26. SunsilkShampooStunningBlackShine450ml(75mlRefillFree).jpg
# 27. SunsilkShampooHairFallSolution170ml(15%Extra).jpg
# 28. GlucoMaxD400gBIB(PowderDrink)(FreeGift).jpg
# 29. VaselineLotionMosquitoDefense50ml.jpg
# 30. LuxBodyWashFreesiaScent&AloeVera245ml.jpg
# 31. BuyVaselineLotionHealthyBright300mlGetvaselinePetroleumJellyFree.jpg
# 32. ComfortFabricConditionerKissofFlowers2L.jpg
# 33. Glow&LovelyCreamWinter50g.jpg
# 34. RinWashingLiquid400Mlbuy2get15%off.jpg
# 35. StandardHorlicks500gmfree50gmDiplomaMilk.jpg
# 36. DoveShampooIntenseRepair380ml.jpg
# 37. VaselineCocoaButter50ml(PetroleumJelly).jpg
# 38. DoveShampooOxygenMoisture380ml.jpg
# 39. JuniorHorlicksHealthandNutritionDrinkStage2(5+Years)BIB500g(PowderDrink).jpg
# 40. Pond’sSuperLightGelMoisturiser49g.jpg
#
# Fetching packshots from page: 11
# 1. DoveShampooHealthyGrow170ml(15%Extra).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 2. ClearShampooAntiHairfallAntiDandruff170ml.jpg
# 3. RinWashingLiquid800ml(Buy2get20%Off).jpg
# 4. RinAdvancedDetergentPowder2Kg.jpg
# 5. Rinfebricsolutionspowerbright1kgContainerFree.jpg
# 6. SurfExcelWashingPowder38gm(Comboof6packs).jpg
# 7. KnorrKrispyFriedChickenMix75g(Bundleof2).jpg
# 8. KnorrSoupHotandSourChicken31g(Bundleof3).jpg
# 9. WheelWashingLaundryBar125g(Bundleof3).jpg
# 10. CifSprayStainlessSteel435ml.jpg
# 11. DoveShampooOxygenMoisture330ml(StylishPurseFree).jpg
# 12. KnorrCupSoupThai12g.jpg
# 13. DoveShampooNourishingOilCare330ml(StylishPurseFree).jpg
# 14. LuxSoapBarVelvetGlow100g.jpg
# 15. DoveShampooHairfallRescue330ml(StylishPurseFree).jpg
# 16. KnorrKrispyFriedChickenMix75g(Bundleof4).jpg
# 17. TresemmeConditionerRichMoisture828ml(UI).jpg
# 18. Glow&LovelyFaceCreamAdvancedMultivitamin80g.jpg
# 19. PepsodentToothpowderGermi-Check50g.jpg
# 20. VaselineLotionAloeFresh200ml.jpg
# 21. SunsilkShampooOnion&JojobaOil375ml.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 22. DoveBeautyBarSoapWhite135g.jpg
# 23. DoveBodyWashGentleExfoliating200ml.jpg
# 24. TresemmeShampooKeratinSmooth580ml.jpg
# 25. SunsilkShampooFreshness375mlScrunchFree.jpg
# 26. VaselineLotionDeepRestore200ml.jpg
# 27. SunsilkShampooLusciouslyThick&Long170ml.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 28. DoveShampooHealthyGrow340ml.jpg
# 29. VimDishwashingBar325g.jpg
# 30. PepsodentToothpasteGermi-Check200g(TiffinBoxFree).jpg
# 31. KnorrSoupThai28g(Bundleof3).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 32. SunsilkLusciouslyThick&LongShampoo380ml.jpg
# 33. PepsodentToothpasteGermi-Check45g.jpg
# 34. CifSprayOven&Grill435ml.jpg
# 35. KnorrforDonation.jpg
# 36. LifebuoySkinCleansingSoapBarCare150g(Bundleof3).jpg
# 37. KnorrCupSoupThai12g(Bundleof12).jpg
# 38. (50%OFF)DomexDisinfectantMultipurposeCleaner500ml.jpg
# 39. KnorrSoupThai28g(Bundleof6).jpg
# 40. VimDiswashingBar300g(Buy5Get20tkOff).jpg
#
# Fetching packshots from page: 12
# 1. (20%OFF)DoveShampooIntenseRepair650ml.jpg
# 2. SunsilkShampooStunningBlackShinePouch75ml.jpg
# 3. KnorrCupSoupThai12g(Bundleof6).jpg
# 4. VaselineLotionHealthyBright400mlKajalFree.jpg
# 5. SunsilkShampooHairFallSolution340mlScrunchFree.jpg
# 6. TresemmeConditionerSilky&Smooth828ml(UI).jpg
# 7. SunsilkShampooLusciouslyThick&Long6ml(Comboof12packs).jpg
# 8. KnorrforDonation.jpg
# 9. VaselineLotionDeepRestore50ml(UI).jpg
# 10. VaselineLotionHealthyBright400ml(Imported50%off).jpg
# 11. DoveShampooOxygenMoisture330ml(15%Extra).jpg
# 12. Buy2SurfExcelSyntheticLaundryDetergentPowder1kgGet 48.TK OFF.jpg
# 13. PepsodentToothpasteGermi-Check85gm.jpg
# 14. SunsilkShampooHijabRefresh340mlScrunchFree.jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 15. SunsilkShampooLusciouslyThick&Long340mlHairScrunchFree.jpg
# 16. VaselineAloeFresh50ml(PetroleumJelly).jpg
# 17. SunsilkShampooStunningBlackShine5.5ml(Comboof12packs).jpg
# 18. SurfExcelWashingPowder18gm(Comboof12packs).jpg
# 19. RinAdvancedSyntheticLaundryDetergentPowder1kg.jpg
# 20. WheelWashingPowder2in1Clean&Fresh2Kg.jpg
# 21. Buy2SurfExcelMaticLiquidDetergentTopLoad1000mlGet20%OFF.jpg
# 22. DoveBodyWashDeeplyNourishing200ml.jpg
# 23. RinAdvancedDetergentPowder500g(10%Extra).jpg
# 24. VaselineLotionHealthyBright300ml(100mlpetroliumJellyFree).jpg
# 25. LuxHandwashRoseandAlmondOilPump-200ml.jpg
# 26. VaselineLotionHealthyBright400ml(Imported).jpg
# 27. DomexToiletCleaningLiquidOceanFresh500ml(FreeGift).jpg
# 28. TresemmeShampooSilky&Smooth828ml(UI).jpg
# <PIL.Image.Image image mode=RGB size=180x180>
# 29. Pond'sVanishingCream28g.jpg
# 30. RinAdvancedSyntheticLaundryDetergentPowder1kg(MugFree).jpg
# 31. Buy2SurfExcelMaticLiquidDetergentTopLoad500mlGet15%OFF.jpg
# 32. KnorrSoupHotandSourChicken31g(Bundleof6).jpg
# 33. CloseupToothpasteMentholFresh45g.jpg
# 34. VaselineLotionDeepRestore400ml(Imported).jpg
# 35. SunsilkShampooHairFallSolution5.5ml(Comboof12packs).jpg
# 36. DoveShampooIntenseRepair330ml(ConditionerFree).jpg
# 37. DoveShampooHealthyGrow330ml(StylishPurseFree).jpg

# %%
# # email
# ol = win32com.client.Dispatch("outlook.application")
# olmailitem = 0x0
# newmail = ol.CreateItem(olmailitem)

# # subject, recipients
# newmail.Subject = "Grammage Packshots - Daraz"
# newmail.To = "shithi.maitra@unilever.com"
# # newmail.To = "avra.barua@unilever.com;"
# # newmail.CC = "safa-e.nafee@unilever.com; rafid-al.mahmood@unilever.com"

# # inline
# def inline(fl_names, idx, seq): return f'<img src="cid: MyId' + str(seq) + '" style="display: block; width: 97px; height: 100px; border: 1px solid"><figcaption><b>Fig</b> ' + fl_names[idx][0:7] + "..." + '</figcaption>'

# # body
# newmail.HTMLbody = f'''
# Dear concern,<br><br>
# Packshot images (total: ''' + str(len(filenames) + len(filenames_gm)) + ''') from <a href="https://www.daraz.com.bd/unilever-bangladesh/">Daraz's UBL page</a> are scraped, per a former requirement. Some examples found in the process are displayed below:<br>
# <br>
# <table style="margin-left: auto; margin-right: auto">
#     <tr><td>''' + inline(filenames, 0, 1) + '''</td>
#         <td>''' + inline(filenames, 1, 2) + '''</td>
#         <td>''' + inline(filenames, 2, 3) + '''</td>
#         <td>''' + inline(filenames, 3, 4) + '''</td>
#         <td>''' + inline(filenames, 4, 5) + '''</td></tr>
# </table>
# <br>
# Packshots missing grammage info (count: ''' + str(len(filenames_gm)) + ''') have been seperated using <b>image processing</b> techniques. Shown below are some instances for your ref.<br>
# <br>
# <table style="margin-left: auto; margin-right: auto">
#     <tr><td>''' + inline(filenames_gm, 0, 6) + '''</td>
#         <td>''' + inline(filenames_gm, 1, 7) + '''</td>
#         <td>''' + inline(filenames_gm, 2, 8) + '''</td>
#         <td>''' + inline(filenames_gm, 3, 9) + '''</td>
#         <td>''' + inline(filenames_gm, 4, 0) + '''</td></tr>
# </table>
# <br>
# The images are in <i>.jpg</i>, with compressed dimensions for easier portability. Please find the attached <i>.zip</i>s. This email was auto generated by <i>win32com</i>.<br><br>
# Thanks,<br>
# Shithi Maitra<br>
# Asst. Manager, Cust. Service Excellence<br>
# Unilever BD Ltd.<br>
# '''

# # attach
# files = [str(Path.cwd()) + "\\" + folder + ".zip", str(Path.cwd()) + "\\" + folder_gm + ".zip"] 
# for file in files: newmail.Attachments.Add(file)

# # embed
# newmail.Attachments.Add(str(output_dir) + "\\" + filenames[0]).PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "MyId1")
# newmail.Attachments.Add(str(output_dir) + "\\" + filenames[1]).PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "MyId2")
# newmail.Attachments.Add(str(output_dir) + "\\" + filenames[2]).PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "MyId3")
# newmail.Attachments.Add(str(output_dir) + "\\" + filenames[3]).PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "MyId4")
# newmail.Attachments.Add(str(output_dir) + "\\" + filenames[4]).PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "MyId5")
# newmail.Attachments.Add(str(output_dir_gm) + "\\" + filenames_gm[0]).PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "MyId6")
# newmail.Attachments.Add(str(output_dir_gm) + "\\" + filenames_gm[1]).PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "MyId7")
# newmail.Attachments.Add(str(output_dir_gm) + "\\" + filenames_gm[2]).PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "MyId8")
# newmail.Attachments.Add(str(output_dir_gm) + "\\" + filenames_gm[3]).PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "MyId9")
# newmail.Attachments.Add(str(output_dir_gm) + "\\" + filenames_gm[4]).PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", "MyId0")

# # send
# newmail.Send()

# %%
# email
ol = win32com.client.Dispatch("outlook.application")
olmailitem = 0x0
newmail = ol.CreateItem(olmailitem)

# subject, recipients
newmail.Subject = "Grammage Packshots - Daraz"
newmail.TO = "avra.barua@unilever.com; safa-e.nafee@unilever.com; rafid-al.mahmood@unilever.com"
newmail.BCC = "shithi30@outlook.com"

# inline
def inline(fl_src, fl_nme, idx): return f'<img src="' + fl_src[idx] + '" style="display: block; width: 97px; height: 100px; border: 1px solid"><figcaption><b>Fig</b> ' + fl_nme[idx][0:7] + "..." + '</figcaption>'

# body
newmail.HTMLbody = f'''
Dear concern,<br><br>
Packshot images (total: ''' + str(len(filenames) + len(filenames_gm)) + ''') from <a href="https://www.daraz.com.bd/unilever-bangladesh/">Daraz's UBL page</a> are scraped, per a former requirement. Some examples found in the process are displayed below:<br>
<br>
<table style="margin-left: auto; margin-right: auto">
    <tr><td>''' + inline(filenames_src, filenames, 0) + '''</td>
        <td>''' + inline(filenames_src, filenames, 1) + '''</td>
        <td>''' + inline(filenames_src, filenames, 2) + '''</td>
        <td>''' + inline(filenames_src, filenames, 3) + '''</td>
        <td>''' + inline(filenames_src, filenames, 4) + '''</td></tr>
</table>
<br>
Packshots missing grammage info (count: ''' + str(len(filenames_gm)) + ''') have been seperated using <b>image processing</b> techniques. Shown below are some instances for your ref.<br>
<br>
<table style="margin-left: auto; margin-right: auto">
    <tr><td>''' + inline(filenames_gm_src, filenames_gm, 0) + '''</td>
        <td>''' + inline(filenames_gm_src, filenames_gm, 1) + '''</td>
        <td>''' + inline(filenames_gm_src, filenames_gm, 2) + '''</td>
        <td>''' + inline(filenames_gm_src, filenames_gm, 3) + '''</td>
        <td>''' + inline(filenames_gm_src, filenames_gm, 4) + '''</td></tr>
</table>
<br>
The images are in <i>.jpg</i>, with compressed dimensions for easier portability. Please find the attached <i>.zip</i>s. This email was auto generated by <i>win32com</i>.<br><br>
Thanks,<br>
Shithi Maitra<br>
Asst. Manager, Cust. Service Excellence<br>
Unilever BD Ltd.<br>
'''

# attach
files = [str(Path.cwd()) + "\\" + folder + ".zip", str(Path.cwd()) + "\\" + folder_gm + ".zip"] 
for file in files: newmail.Attachments.Add(file)

# send
newmail.Send()

# %%
# stats
print("Total packshots found: " + str(len(filenames) + len(filenames_gm)))
elapsed_time = str(round((time.time() - start_time) / 60.00, 2))
print("Elapsed time to run script (mins): " + elapsed_time)
# Out:
# Total packshots found: 529
# Elapsed time to run script (mins): 6.95
